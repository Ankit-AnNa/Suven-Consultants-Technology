# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=pd.read_csv('users[1].csv')
b=pd.read_csv('views[1].csv')
c=pd.read_csv('posts[1].csv')

# %%
a
# Out:
#                           _id                  name  gender      academics
# 0    5d60098a653a331687083238  Nivesh Singh Chauhan    male  undergraduate
# 1    5d610ae1653a331687083239         Gaurav Sharma    male       graduate
# 2    5d618359fc5fcf3bdd9a0910         Akshay Mishra    male  undergraduate
# 3    5d6d2bb87fa40e1417a49315        Saksham Mathur    male  undergraduate
# 4    5d7c994d5720533e15c3b1e9         Varun Chowhan    male  undergraduate
# ..                        ...                   ...     ...            ...
# 113  5ed35aa376027d35905cca67                 Steve    male       graduate
# 114  5ed3737976027d35905ccaa2        Himanshu Singh    male  undergraduate
# 115  5ed3748576027d35905ccaab           Parth Vijay    male  undergraduate
# 116  5ed3cbcbbd514d602c1530a7       Abhishek Mishra    male  undergraduate
# 117  5ed3e898bd514d602c1530de          gauri raskar  female       graduate
#
# [118 rows x 4 columns]

# %%
a['gender']=a['gender'].str.capitalize()
a['academics']=a['academics'].str.capitalize()
a['name']=a['name'].str.capitalize()
a['name']=a['name'].str.title()
a.rename(columns = {'_id':'ID','name': 'NAME','gender':'GENDER','academics':'ACADEMICS'},inplace = True)
a
# Out:
#                            ID                  NAME  GENDER      ACADEMICS
# 0    5d60098a653a331687083238  Nivesh Singh Chauhan    Male  Undergraduate
# 1    5d610ae1653a331687083239         Gaurav Sharma    Male       Graduate
# 2    5d618359fc5fcf3bdd9a0910         Akshay Mishra    Male  Undergraduate
# 3    5d6d2bb87fa40e1417a49315        Saksham Mathur    Male  Undergraduate
# 4    5d7c994d5720533e15c3b1e9         Varun Chowhan    Male  Undergraduate
# ..                        ...                   ...     ...            ...
# 113  5ed35aa376027d35905cca67                 Steve    Male       Graduate
# 114  5ed3737976027d35905ccaa2        Himanshu Singh    Male  Undergraduate
# 115  5ed3748576027d35905ccaab           Parth Vijay    Male  Undergraduate
# 116  5ed3cbcbbd514d602c1530a7       Abhishek Mishra    Male  Undergraduate
# 117  5ed3e898bd514d602c1530de          Gauri Raskar  Female       Graduate
#
# [118 rows x 4 columns]

# %%
b
# Out:
#                        user_id                   post_id  \
# 0     5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e
# 1     5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6
# 2     5ed0defa76027d35905cc2de  5eac305f10426255a7aa9dd3
# 3     5ed0defa76027d35905cc2de  5ed1ff0276027d35905cc60d
# 4     5ed0defa76027d35905cc2de  5ed3820f76027d35905ccac8
# ...                        ...                       ...
# 1444  5d60098a653a331687083238  5e7a60edcfc8b713f5ac7d82
# 1445  5d60098a653a331687083238  5e7a629ccfc8b713f5ac7d84
# 1446  5d60098a653a331687083238  5e7b1e65cfc8b713f5ac7d90
# 1447  5d60098a653a331687083238  5e7cc074cfc8b713f5ac7db0
# 1448  5d60098a653a331687083238  5e1029f22a37d20505da2a79
#
#                      timestamp
# 0     2020-06-01T10:46:45.131Z
# 1     2020-06-01T09:39:20.021Z
# 2     2020-06-01T08:12:42.682Z
# 3     2020-06-01T08:10:23.880Z
# 4     2020-06-01T08:08:54.124Z
# ...                        ...
# 1444  2020-03-26T19:03:55.284Z
# 1445  2020-03-26T19:01:42.384Z
# 1446  2020-03-26T19:00:25.693Z
# 1447  2020-03-26T18:49:14.721Z
# 1448  2020-03-26T18:25:45.637Z
#
# [1449 rows x 3 columns]

# %%
b.rename(columns = {'user_id': 'ID','post_id':'POST-ID','timestamp':'TIMESTAMP'},inplace = True)
b
# Out:
#                             ID                   POST-ID  \
# 0     5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e
# 1     5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6
# 2     5ed0defa76027d35905cc2de  5eac305f10426255a7aa9dd3
# 3     5ed0defa76027d35905cc2de  5ed1ff0276027d35905cc60d
# 4     5ed0defa76027d35905cc2de  5ed3820f76027d35905ccac8
# ...                        ...                       ...
# 1444  5d60098a653a331687083238  5e7a60edcfc8b713f5ac7d82
# 1445  5d60098a653a331687083238  5e7a629ccfc8b713f5ac7d84
# 1446  5d60098a653a331687083238  5e7b1e65cfc8b713f5ac7d90
# 1447  5d60098a653a331687083238  5e7cc074cfc8b713f5ac7db0
# 1448  5d60098a653a331687083238  5e1029f22a37d20505da2a79
#
#                      TIMESTAMP
# 0     2020-06-01T10:46:45.131Z
# 1     2020-06-01T09:39:20.021Z
# 2     2020-06-01T08:12:42.682Z
# 3     2020-06-01T08:10:23.880Z
# 4     2020-06-01T08:08:54.124Z
# ...                        ...
# 1444  2020-03-26T19:03:55.284Z
# 1445  2020-03-26T19:01:42.384Z
# 1446  2020-03-26T19:00:25.693Z
# 1447  2020-03-26T18:49:14.721Z
# 1448  2020-03-26T18:25:45.637Z
#
# [1449 rows x 3 columns]

# %%
c
# Out:
#                           _id  \
# 0    5d62abaa65218653a132c956
# 1    5d6d39567fa40e1417a4931c
# 2    5d7d23315720533e15c3b1ee
# 3    5d7d405e5720533e15c3b1f3
# 4    5d80dfbc6c53455f896e600e
# ..                        ...
# 488  5ed3791976027d35905ccab6
# 489  5ed3820f76027d35905ccac8
# 490  5ed3ef4cbd514d602c1530f2
# 491  5ed415c6bd514d602c15312d
# 492  5ed4cbadbd514d602c1531a6
#
#                                                  title  \
# 0                                          hello there
# 1                                            Ml and AI
# 2                        What is an Operating System ?
# 3                                           Lord Shiva
# 4                         How Competition law evolved?
# ..                                                 ...
# 488                         CI/CD using GitHub Actions
# 489  Configure Docker with Django; PostgreSQL; Pg-a...
# 490                              Recommendation Engine
# 491          Face Recognition using Transfer Learning.
# 492  Configure CI/CD Pipeline in GitLab and deploym...
#
#                                               category  post_type
# 0                                  Plant Biotechnology       blog
# 1    Artificial Intelligence|Machine Learning|Infor...       blog
# 2                                    Operating Systems       blog
# 3                                             Drawings    artwork
# 4                                     Competition Laws       blog
# ..                                                 ...        ...
# 488         Computer Technology|Information Technology       blog
# 489  Computer Technology|Computer Application|Infor...       blog
# 490                                                NaN    project
# 491                                Science; Technology      skill
# 492  Computer Technology|Computer Application|Infor...       blog
#
# [493 rows x 4 columns]

# %%
c['title']=c['title'].str.title()
c['category']=c['category'].str.title()
c[' post_type']=c[' post_type'].str.capitalize()
c.rename(columns = {'_id': 'POST-ID',' post_type':'POST-TYPE','title':'TITLE','category':'CATEGORY'},inplace = True)
c
# Out:
#                       POST-ID  \
# 0    5d62abaa65218653a132c956
# 1    5d6d39567fa40e1417a4931c
# 2    5d7d23315720533e15c3b1ee
# 3    5d7d405e5720533e15c3b1f3
# 4    5d80dfbc6c53455f896e600e
# ..                        ...
# 488  5ed3791976027d35905ccab6
# 489  5ed3820f76027d35905ccac8
# 490  5ed3ef4cbd514d602c1530f2
# 491  5ed415c6bd514d602c15312d
# 492  5ed4cbadbd514d602c1531a6
#
#                                                  TITLE  \
# 0                                          Hello There
# 1                                            Ml And Ai
# 2                        What Is An Operating System ?
# 3                                           Lord Shiva
# 4                         How Competition Law Evolved?
# ..                                                 ...
# 488                         Ci/Cd Using Github Actions
# 489  Configure Docker With Django; Postgresql; Pg-A...
# 490                              Recommendation Engine
# 491          Face Recognition Using Transfer Learning.
# 492  Configure Ci/Cd Pipeline In Gitlab And Deploym...
#
#                                               CATEGORY POST-TYPE
# 0                                  Plant Biotechnology      Blog
# 1    Artificial Intelligence|Machine Learning|Infor...      Blog
# 2                                    Operating Systems      Blog
# 3                                             Drawings   Artwork
# 4                                     Competition Laws      Blog
# ..                                                 ...       ...
# 488         Computer Technology|Information Technology      Blog
# 489  Computer Technology|Computer Application|Infor...      Blog
# 490                                                NaN   Project
# 491                                Science; Technology     Skill
# 492  Computer Technology|Computer Application|Infor...      Blog
#
# [493 rows x 4 columns]

# %%
d=b.groupby(['ID'])
e=d.first().reset_index()
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         118 non-null    object
#  1   POST-ID    118 non-null    object
#  2   TIMESTAMP  118 non-null    object
# dtypes: object(3)
# memory usage: 2.9+ KB

# %%
e['TIMESTAMP']= pd.to_datetime(e['TIMESTAMP'])
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         118 non-null    object
#  1   POST-ID    118 non-null    object
#  2   TIMESTAMP  118 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), object(2)
# memory usage: 2.9+ KB

# %%
df_new = pd.merge(a, e, how='right',on='ID')

# %%
df_new
# Out:
#                            ID                  NAME  GENDER      ACADEMICS  \
# 0    5d60098a653a331687083238  Nivesh Singh Chauhan    Male  Undergraduate
# 1    5d610ae1653a331687083239         Gaurav Sharma    Male       Graduate
# 2    5d618359fc5fcf3bdd9a0910         Akshay Mishra    Male  Undergraduate
# 3    5d6d2bb87fa40e1417a49315        Saksham Mathur    Male  Undergraduate
# 4    5d7c994d5720533e15c3b1e9         Varun Chowhan    Male  Undergraduate
# ..                        ...                   ...     ...            ...
# 113  5ed35aa376027d35905cca67                 Steve    Male       Graduate
# 114  5ed3737976027d35905ccaa2        Himanshu Singh    Male  Undergraduate
# 115  5ed3748576027d35905ccaab           Parth Vijay    Male  Undergraduate
# 116  5ed3cbcbbd514d602c1530a7       Abhishek Mishra    Male  Undergraduate
# 117  5ed3e898bd514d602c1530de          Gauri Raskar  Female       Graduate
#
#                       POST-ID                        TIMESTAMP
# 0    5ed3820f76027d35905ccac8 2020-05-31 18:01:54.308000+00:00
# 1    5ed13d2876027d35905cc4c2 2020-05-29 18:50:23.193000+00:00
# 2    5ed09ad076027d35905cc15f 2020-05-30 21:47:46.971000+00:00
# 3    5ecce8a5eaff6b0c3a58a5e9 2020-05-26 20:18:56.456000+00:00
# 4    5ed1ff0276027d35905cc60d 2020-05-31 05:16:59.953000+00:00
# ..                        ...                              ...
# 113  5ed141aa76027d35905cc4c9 2020-05-31 10:54:16.998000+00:00
# 114  5ed1ff0276027d35905cc60d 2020-05-31 09:09:07.321000+00:00
# 115  5ed4cbadbd514d602c1531a6 2020-06-01 09:39:20.021000+00:00
# 116  5ed1ff0276027d35905cc60d 2020-05-31 16:16:51.523000+00:00
# 117  5ecf818376027d35905cbf03 2020-05-31 18:56:56.215000+00:00
#
# [118 rows x 6 columns]

# %%
df_1 = pd.merge(c,df_new, how='right',on='POST-ID')
df_1
# Out:
#                       POST-ID  \
# 0    5d7d23315720533e15c3b1ee
# 1    5d9b3514979d5962253c2f90
# 2    5de8d73249e8203ff9219a74
# 3    5dea816a42a8854bf6eaba89
# 4    5df64ad1cc709107827fb3dd
# ..                        ...
# 113  5ed229d976027d35905cc666
# 114  5ed2383776027d35905cc6ca
# 115  5ed3476576027d35905cca1d
# 116  5ed3820f76027d35905ccac8
# 117  5ed4cbadbd514d602c1531a6
#
#                                                  TITLE  \
# 0                        What Is An Operating System ?
# 1                                         Biodiversity
# 2                                   Promotional Video.
# 3                                   The Periodic Table
# 4                                           The Chosen
# ..                                                 ...
# 113                                    Cloud Computing
# 114                                       Self Belief.
# 115                               Aws Cli Setup In Mac
# 116  Configure Docker With Django; Postgresql; Pg-A...
# 117  Configure Ci/Cd Pipeline In Gitlab And Deploym...
#
#                                               CATEGORY POST-TYPE  \
# 0                                    Operating Systems      Blog
# 1                                           Eco System      Blog
# 2                                        Video Editing     Skill
# 3                                  Inorganic Chemistry      Blog
# 4                                             Drawings   Artwork
# ..                                                 ...       ...
# 113  Computer Technology|Computation|Computer Appli...      Blog
# 114                             Typography|Pen And Ink   Artwork
# 115                                         Technology     Skill
# 116  Computer Technology|Computer Application|Infor...      Blog
# 117  Computer Technology|Computer Application|Infor...      Blog
#
#                            ID                  NAME  GENDER      ACADEMICS  \
# 0    5ea83e8810426255a7aa9bf2        Abhishek Kumar    Male  Undergraduate
# 1    5d90fc1a641ef364939fb6cc          Boshi Kaviya  Female       Graduate
# 2    5ecfdaa976027d35905cc02c           Shreya Maji  Female  Undergraduate
# 3    5ded443342a8854bf6eaba9a    Maaz Ahmad Rabbani    Male  Undergraduate
# 4    5e8cbd92a3258347b42f2699          Ayush Sharma    Male       Graduate
# ..                        ...                   ...     ...            ...
# 113  5ed0dfec76027d35905cc2ec  Parth Praveen Deokar    Male       Graduate
# 114  5ed2672576027d35905cc7f6          Arman Lalani    Male  Undergraduate
# 115  5ed13bb076027d35905cc4ba      Saumik Satapathy    Male       Graduate
# 116  5d60098a653a331687083238  Nivesh Singh Chauhan    Male  Undergraduate
# 117  5ed3748576027d35905ccaab           Parth Vijay    Male  Undergraduate
#
#                            TIMESTAMP
# 0   2020-04-30 11:03:52.741000+00:00
# 1   2020-04-30 16:35:33.590000+00:00
# 2   2020-05-28 15:52:59.443000+00:00
# 3   2020-05-11 12:09:04.357000+00:00
# 4   2020-04-07 17:59:55.597000+00:00
# ..                               ...
# 113 2020-05-30 09:39:55.346000+00:00
# 114 2020-05-30 15:00:43.399000+00:00
# 115 2020-05-31 11:57:27.369000+00:00
# 116 2020-05-31 18:01:54.308000+00:00
# 117 2020-06-01 09:39:20.021000+00:00
#
# [118 rows x 9 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 117
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   POST-ID    118 non-null    object
#  1   TITLE      118 non-null    object
#  2   CATEGORY   110 non-null    object
#  3   POST-TYPE  118 non-null    object
#  4   ID         118 non-null    object
#  5   NAME       118 non-null    object
#  6   GENDER     118 non-null    object
#  7   ACADEMICS  118 non-null    object
#  8   TIMESTAMP  118 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), object(8)
# memory usage: 9.2+ KB

# %%
df_2=df_1[['ID','POST-ID','NAME','GENDER','ACADEMICS','TITLE','CATEGORY','POST-TYPE','TIMESTAMP']]

# %%
df_2
# Out:
#                            ID                   POST-ID                  NAME  \
# 0    5ea83e8810426255a7aa9bf2  5d7d23315720533e15c3b1ee        Abhishek Kumar
# 1    5d90fc1a641ef364939fb6cc  5d9b3514979d5962253c2f90          Boshi Kaviya
# 2    5ecfdaa976027d35905cc02c  5de8d73249e8203ff9219a74           Shreya Maji
# 3    5ded443342a8854bf6eaba9a  5dea816a42a8854bf6eaba89    Maaz Ahmad Rabbani
# 4    5e8cbd92a3258347b42f2699  5df64ad1cc709107827fb3dd          Ayush Sharma
# ..                        ...                       ...                   ...
# 113  5ed0dfec76027d35905cc2ec  5ed229d976027d35905cc666  Parth Praveen Deokar
# 114  5ed2672576027d35905cc7f6  5ed2383776027d35905cc6ca          Arman Lalani
# 115  5ed13bb076027d35905cc4ba  5ed3476576027d35905cca1d      Saumik Satapathy
# 116  5d60098a653a331687083238  5ed3820f76027d35905ccac8  Nivesh Singh Chauhan
# 117  5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6           Parth Vijay
#
#      GENDER      ACADEMICS                                              TITLE  \
# 0      Male  Undergraduate                      What Is An Operating System ?
# 1    Female       Graduate                                       Biodiversity
# 2    Female  Undergraduate                                 Promotional Video.
# 3      Male  Undergraduate                                 The Periodic Table
# 4      Male       Graduate                                         The Chosen
# ..      ...            ...                                                ...
# 113    Male       Graduate                                    Cloud Computing
# 114    Male  Undergraduate                                       Self Belief.
# 115    Male       Graduate                               Aws Cli Setup In Mac
# 116    Male  Undergraduate  Configure Docker With Django; Postgresql; Pg-A...
# 117    Male  Undergraduate  Configure Ci/Cd Pipeline In Gitlab And Deploym...
#
#                                               CATEGORY POST-TYPE  \
# 0                                    Operating Systems      Blog
# 1                                           Eco System      Blog
# 2                                        Video Editing     Skill
# 3                                  Inorganic Chemistry      Blog
# 4                                             Drawings   Artwork
# ..                                                 ...       ...
# 113  Computer Technology|Computation|Computer Appli...      Blog
# 114                             Typography|Pen And Ink   Artwork
# 115                                         Technology     Skill
# 116  Computer Technology|Computer Application|Infor...      Blog
# 117  Computer Technology|Computer Application|Infor...      Blog
#
#                            TIMESTAMP
# 0   2020-04-30 11:03:52.741000+00:00
# 1   2020-04-30 16:35:33.590000+00:00
# 2   2020-05-28 15:52:59.443000+00:00
# 3   2020-05-11 12:09:04.357000+00:00
# 4   2020-04-07 17:59:55.597000+00:00
# ..                               ...
# 113 2020-05-30 09:39:55.346000+00:00
# 114 2020-05-30 15:00:43.399000+00:00
# 115 2020-05-31 11:57:27.369000+00:00
# 116 2020-05-31 18:01:54.308000+00:00
# 117 2020-06-01 09:39:20.021000+00:00
#
# [118 rows x 9 columns]

# %%
p=df_2['GENDER'].value_counts().reset_index()
p
# Out:
#        index  GENDER
# 0       Male      72
# 1     Female      44
# 2  Undefined       2

# %%
m=df_2[['GENDER','NAME']]
m.groupby(['GENDER','NAME']).first()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Female, Aayushree Khokhar), (Female, Akhila Kota), (Female, Akshra Mathur), (Female, Aleena Francis), (Female, Angelina Christi), (Female, Boshi Kaviya), (Female, Chavi Maheshwari.), (Female, Fauziya Shaikh), (Female, Gauri Raskar), (Female, Harshita), (Female, Ilupeju Ayokunnumi), (Female, Isha), (Female, Isis Amador), (Female, Jivintika Saini), (Female, Kanika Sharma), (Female, Kirti Ranka), (Female, Lipika Moharana), (Female, Muskan Assudani), (Female, Neha), (Female, Neha Malik), (Female, Niriksha Sharma), (Female, Nisha), (Female, P. Gayatri), (Female, Prakasika.M.P), (Female, Pratishtha Bhelonde), (Female, Rashi Jain), (Female, Rashi Rathi), (Female, Sahana B), (Female, Saumya Singh), (Female, Shailja Tripathi), (Female, Shanya), (Female, Shivani Gaba), (Female, Shraddha Handa), (Female, Shreya Maji), (Female, Shriya Kataria), (Female, Smriti), (Female, Sneha Shekhawat), (Female, Srinidhi A), (Female, Suhasi Gupta), (Female, Suman Ray), (Female, Tavisha), (Female, Udita Somani), (Female, Varsha), (Female, Yoshita), (Male, Aanjan Prasath G), (Male, Abhinav Mishra), (Male, Abhishank Gupta), (Male, Abhishek Kumar), (Male, Abhishek Mishra), (Male, Akshay Mishra), (Male, Ankush Chavan), (Male, Apurba), (Male, Arman Lalani), (Male, Arunav Moitra), (Male, Arup), (Male, Aryan Malakar), (Male, Ashish), (Male, Asif Hossain), (Male, Avimanyu Samanta), (Male, Ayush Gupta), (Male, Ayush Sharma), (Male, Bhargav Prakash), (Male, Bhaskar Mishra), (Male, Bobil Singh), (Male, Deep Patel), (Male, Deepak Kumar), (Male, Dipak Jadhav), (Male, Elbassraoui Yassine), (Male, Gaurav Sharma), (Male, Gouranga Jena), (Male, Harbind Singh), (Male, Harishankar Dubey), (Male, Harsh Nigam), (Male, Himanshu Singh), (Male, Hritik Chaturvedi), (Male, Keshant Sharma), (Male, Kshitij Alawandi), (Male, Kshitij Anand), (Male, Kushagra Sharma), (Male, Maaz Ahmad Rabbani), (Male, Manish Nehra), (Male, Massimo Puppo), (Male, Mohd Junaid Mansuri), (Male, Mukesh), (Male, Mukesh Kumar Mahto), (Male, Nachiket Khatri), (Male, Nihal Singh Shekhawat), (Male, Nikhil Sharma), (Male, Nimish Sharma), (Male, Nischaya Sharma), (Male, Nivesh Singh Chauhan), (Male, Ojasvi Arya), (Male, Parth Praveen Deokar), (Male, Parth Vijay), (Male, Parvez Khan), (Male, Priya Ranjan), (Male, Raghunath), (Male, Raghunath Dhandapani), (Male, Rahul Agarwal), (Male, Rajesha Ct), ...]
#
# [118 rows x 0 columns]

# %%
q=df_2['ACADEMICS'].value_counts().reset_index()
q
# Out:
#            index  ACADEMICS
# 0  Undergraduate         68
# 1       Graduate         48
# 2      Undefined          2

# %%
n=df_2[['ACADEMICS','NAME']]
n.groupby(['ACADEMICS','NAME']).first()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Graduate, Akhila Kota), (Graduate, Apurba), (Graduate, Arunav Moitra), (Graduate, Arup), (Graduate, Ashish), (Graduate, Avimanyu Samanta), (Graduate, Ayush Sharma), (Graduate, Bobil Singh), (Graduate, Boshi Kaviya), (Graduate, Dipak Jadhav), (Graduate, Elbassraoui Yassine), (Graduate, Gaurav Sharma), (Graduate, Gauri Raskar), (Graduate, Gouranga Jena), (Graduate, Harishankar Dubey), (Graduate, Ilupeju Ayokunnumi), (Graduate, Keshant Sharma), (Graduate, Kirti Ranka), (Graduate, Kshitij Alawandi), (Graduate, Lipika Moharana), (Graduate, Mohd Junaid Mansuri), (Graduate, Mukesh), (Graduate, Mukesh Kumar Mahto), (Graduate, Neha), (Graduate, Neha Malik), (Graduate, Nihal Singh Shekhawat), (Graduate, Nikhil Sharma), (Graduate, Nisha), (Graduate, Parth Praveen Deokar), (Graduate, Priya Ranjan), (Graduate, Raghunath), (Graduate, Raghunath Dhandapani), (Graduate, Rahul Agarwal), (Graduate, Rajesha Ct), (Graduate, Rossend Bonàs Miró), (Graduate, Saumik Satapathy), (Graduate, Shailja Tripathi), (Graduate, Shivani Gaba), (Graduate, Sneha Shekhawat), (Graduate, Soumya Kumar), (Graduate, Steve), (Graduate, Suman Ray), (Graduate, Tarini Prasad Ray), (Graduate, Thesocialcomment), (Graduate, Utkarsh Saini), (Graduate, Varsha), (Graduate, Vipul S Redey), (Graduate, Wael Onsy), (Undefined, Apoorva Rana), (Undefined, Gretchen), (Undergraduate, Aanjan Prasath G), (Undergraduate, Aayushree Khokhar), (Undergraduate, Abhinav Mishra), (Undergraduate, Abhishank Gupta), (Undergraduate, Abhishek Kumar), (Undergraduate, Abhishek Mishra), (Undergraduate, Akshay Mishra), (Undergraduate, Akshra Mathur), (Undergraduate, Aleena Francis), (Undergraduate, Angelina Christi), (Undergraduate, Ankush Chavan), (Undergraduate, Arman Lalani), (Undergraduate, Aryan Malakar), (Undergraduate, Asif Hossain), (Undergraduate, Ayush Gupta), (Undergraduate, Bhargav Prakash), (Undergraduate, Bhaskar Mishra), (Undergraduate, Chavi Maheshwari.), (Undergraduate, Deep Patel), (Undergraduate, Deepak Kumar), (Undergraduate, Fauziya Shaikh), (Undergraduate, Harbind Singh), (Undergraduate, Harsh Nigam), (Undergraduate, Harshita), (Undergraduate, Himanshu Singh), (Undergraduate, Hritik Chaturvedi), (Undergraduate, Isha), (Undergraduate, Isis Amador), (Undergraduate, Jivintika Saini), (Undergraduate, Kanika Sharma), (Undergraduate, Kshitij Anand), (Undergraduate, Kushagra Sharma), (Undergraduate, Maaz Ahmad Rabbani), (Undergraduate, Manish Nehra), (Undergraduate, Massimo Puppo), (Undergraduate, Muskan Assudani), (Undergraduate, Nachiket Khatri), (Undergraduate, Nimish Sharma), (Undergraduate, Niriksha Sharma), (Undergraduate, Nischaya Sharma), (Undergraduate, Nivesh Singh Chauhan), (Undergraduate, Ojasvi Arya), (Undergraduate, P. Gayatri), (Undergraduate, Parth Vijay), (Undergraduate, Parvez Khan), (Undergraduate, Prakasika.M.P), (Undergraduate, Pratishtha Bhelonde), (Undergraduate, Rashi Jain), (Undergraduate, Rashi Rathi), (Undergraduate, Rushikesh Chaudhari), ...]
#
# [118 rows x 0 columns]

# %%
r=df_2['POST-TYPE'].value_counts().reset_index()
r
# Out:
#      index  POST-TYPE
# 0     Blog         62
# 1  Artwork         39
# 2    Skill          9
# 3  Project          8

# %%
l=df_2[['POST-TYPE','NAME']]
l.groupby(['POST-TYPE','NAME']).first()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Artwork, Aayushree Khokhar), (Artwork, Abhishank Gupta), (Artwork, Akshra Mathur), (Artwork, Aleena Francis), (Artwork, Angelina Christi), (Artwork, Apoorva Rana), (Artwork, Arman Lalani), (Artwork, Arunav Moitra), (Artwork, Ashish), (Artwork, Asif Hossain), (Artwork, Ayush Gupta), (Artwork, Ayush Sharma), (Artwork, Bhargav Prakash), (Artwork, Chavi Maheshwari.), (Artwork, Elbassraoui Yassine), (Artwork, Fauziya Shaikh), (Artwork, Harsh Nigam), (Artwork, Massimo Puppo), (Artwork, Neha), (Artwork, Nihal Singh Shekhawat), (Artwork, Niriksha Sharma), (Artwork, Nisha), (Artwork, Ojasvi Arya), (Artwork, P. Gayatri), (Artwork, Parvez Khan), (Artwork, Prakasika.M.P), (Artwork, Rashi Jain), (Artwork, Rushikesh Chaudhari), (Artwork, Saksham Mathur), (Artwork, Shanya), (Artwork, Shriya Kataria), (Artwork, Smriti), (Artwork, Sneha Shekhawat), (Artwork, Srinidhi A), (Artwork, Suhasi Gupta), (Artwork, Sumit Gangwani), (Artwork, Varsha), (Artwork, Wael Onsy), (Artwork, Yoshita), (Blog, Aanjan Prasath G), (Blog, Abhishek Kumar), (Blog, Abhishek Mishra), (Blog, Akhila Kota), (Blog, Akshay Mishra), (Blog, Ankush Chavan), (Blog, Apurba), (Blog, Arup), (Blog, Aryan Malakar), (Blog, Avimanyu Samanta), (Blog, Bobil Singh), (Blog, Boshi Kaviya), (Blog, Deep Patel), (Blog, Deepak Kumar), (Blog, Dipak Jadhav), (Blog, Gauri Raskar), (Blog, Gouranga Jena), (Blog, Gretchen), (Blog, Harbind Singh), (Blog, Harishankar Dubey), (Blog, Harshita), (Blog, Himanshu Singh), (Blog, Hritik Chaturvedi), (Blog, Ilupeju Ayokunnumi), (Blog, Isha), (Blog, Isis Amador), (Blog, Kanika Sharma), (Blog, Keshant Sharma), (Blog, Kirti Ranka), (Blog, Kshitij Alawandi), (Blog, Kshitij Anand), (Blog, Lipika Moharana), (Blog, Maaz Ahmad Rabbani), (Blog, Manish Nehra), (Blog, Mukesh), (Blog, Mukesh Kumar Mahto), (Blog, Nachiket Khatri), (Blog, Nikhil Sharma), (Blog, Nischaya Sharma), (Blog, Nivesh Singh Chauhan), (Blog, Parth Praveen Deokar), (Blog, Parth Vijay), (Blog, Pratishtha Bhelonde), (Blog, Priya Ranjan), (Blog, Raghunath), (Blog, Raghunath Dhandapani), (Blog, Rajesha Ct), (Blog, Rashi Rathi), (Blog, Rossend Bonàs Miró), (Blog, Sahana B), (Blog, Saumya Singh), (Blog, Shailja Tripathi), (Blog, Shivani Gaba), (Blog, Shraddha Handa), (Blog, Shubham Kumar), (Blog, Soumya Kumar), (Blog, Steve), (Blog, Suman Ray), (Blog, Sushil), (Blog, Udita Somani), (Blog, Utkarsh Saini), ...]
#
# [118 rows x 0 columns]

# %%
s=df_2['CATEGORY'].value_counts().reset_index()
s[:10]
# Out:
#                                             index  CATEGORY
# 0                                     Photography        14
# 1             Computer Technology|Cloud Computing        13
# 2                                        Drawings         9
# 3                                        Painting         5
# 4                      Geography|Indian Geography         4
# 5                Computer Technology|Data Science         4
# 6            Computer Technology|Machine Learning         4
# 7  Marketing|Promotion And Distribution Decisions         3
# 8                                      Technology         3
# 9                           Marketing|Advertising         3

# %%
plt.figure(figsize=(12,7))
plt.pie(s['CATEGORY'][:10],labels=s['index'][:10],autopct='%0.2f%%',shadow=True,counterclock=True)
plt.title('PRECENTAGE RECORD OF CATEGORPY THROUG PIE CHART',fontsize=20)
plt.show()

# %%
t=df_2['TITLE'].value_counts().reset_index()
t[:10]
# Out:
#                                                index  TITLE
# 0                 Understanding Cloud Computing(Aws)      7
# 1     Aws Services And How To Launch Os On Aws Cloud      5
# 2    Integrating Machine Learning With Devops(Mlops)      4
# 3                                 Gan'S Introduction      3
# 4  Benefits Of Guest Posting To Both Writers And ...      3
# 5       Importance Of Digital Marketing For Startups      3
# 6                                    Cloud Computing      3
# 7  Designing Cmos Circuit From Boolean Expression...      3
# 8                      Guest Posting At Free Of Cost      2
# 9                       Stand Alone And Stand Apart.      2

# %%
plt.figure(figsize=(12,7))
plt.pie(t['TITLE'][:10],labels=t['index'][:10],autopct='%0.2f%%',shadow=True,counterclock=True)
plt.title('PRECENTAGE RECORD OF TITLE THROUG PIE CHART',fontsize=20)
plt.show()

# %%
df_2['YEAR'] = df_2['TIMESTAMP'].dt.year 
df_2['MONTH'] = df_2['TIMESTAMP'].dt.month 
df_2['DAY'] = df_2['TIMESTAMP'].dt.day 
df_2['HOUR'] = df_2['TIMESTAMP'].dt.hour 
df_2['MINUTE'] = df_2['TIMESTAMP'].dt.minute
# Out:
# <ipython-input-27-fcc20a22c738>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['YEAR'] = df_2['TIMESTAMP'].dt.year
# <ipython-input-27-fcc20a22c738>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['MONTH'] = df_2['TIMESTAMP'].dt.month
# <ipython-input-27-fcc20a22c738>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['DAY'] = df_2['TIMESTAMP'].dt.day
# <ipython-input-27-fcc20a22c738>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['HOUR'] = df_2['TIMESTAMP'].dt.hour
# <ipython-input-27-fcc20a22c738>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['MINUTE'] = df_2['TIMESTAMP'].dt.minute

# %%
df_2
# Out:
#                            ID                   POST-ID                  NAME  \
# 0    5ea83e8810426255a7aa9bf2  5d7d23315720533e15c3b1ee        Abhishek Kumar
# 1    5d90fc1a641ef364939fb6cc  5d9b3514979d5962253c2f90          Boshi Kaviya
# 2    5ecfdaa976027d35905cc02c  5de8d73249e8203ff9219a74           Shreya Maji
# 3    5ded443342a8854bf6eaba9a  5dea816a42a8854bf6eaba89    Maaz Ahmad Rabbani
# 4    5e8cbd92a3258347b42f2699  5df64ad1cc709107827fb3dd          Ayush Sharma
# ..                        ...                       ...                   ...
# 113  5ed0dfec76027d35905cc2ec  5ed229d976027d35905cc666  Parth Praveen Deokar
# 114  5ed2672576027d35905cc7f6  5ed2383776027d35905cc6ca          Arman Lalani
# 115  5ed13bb076027d35905cc4ba  5ed3476576027d35905cca1d      Saumik Satapathy
# 116  5d60098a653a331687083238  5ed3820f76027d35905ccac8  Nivesh Singh Chauhan
# 117  5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6           Parth Vijay
#
#      GENDER      ACADEMICS                                              TITLE  \
# 0      Male  Undergraduate                      What Is An Operating System ?
# 1    Female       Graduate                                       Biodiversity
# 2    Female  Undergraduate                                 Promotional Video.
# 3      Male  Undergraduate                                 The Periodic Table
# 4      Male       Graduate                                         The Chosen
# ..      ...            ...                                                ...
# 113    Male       Graduate                                    Cloud Computing
# 114    Male  Undergraduate                                       Self Belief.
# 115    Male       Graduate                               Aws Cli Setup In Mac
# 116    Male  Undergraduate  Configure Docker With Django; Postgresql; Pg-A...
# 117    Male  Undergraduate  Configure Ci/Cd Pipeline In Gitlab And Deploym...
#
#                                               CATEGORY POST-TYPE  \
# 0                                    Operating Systems      Blog
# 1                                           Eco System      Blog
# 2                                        Video Editing     Skill
# 3                                  Inorganic Chemistry      Blog
# 4                                             Drawings   Artwork
# ..                                                 ...       ...
# 113  Computer Technology|Computation|Computer Appli...      Blog
# 114                             Typography|Pen And Ink   Artwork
# 115                                         Technology     Skill
# 116  Computer Technology|Computer Application|Infor...      Blog
# 117  Computer Technology|Computer Application|Infor...      Blog
#
#                            TIMESTAMP  YEAR  MONTH  DAY  HOUR  MINUTE
# 0   2020-04-30 11:03:52.741000+00:00  2020      4   30    11       3
# 1   2020-04-30 16:35:33.590000+00:00  2020      4   30    16      35
# 2   2020-05-28 15:52:59.443000+00:00  2020      5   28    15      52
# 3   2020-05-11 12:09:04.357000+00:00  2020      5   11    12       9
# 4   2020-04-07 17:59:55.597000+00:00  2020      4    7    17      59
# ..                               ...   ...    ...  ...   ...     ...
# 113 2020-05-30 09:39:55.346000+00:00  2020      5   30     9      39
# 114 2020-05-30 15:00:43.399000+00:00  2020      5   30    15       0
# 115 2020-05-31 11:57:27.369000+00:00  2020      5   31    11      57
# 116 2020-05-31 18:01:54.308000+00:00  2020      5   31    18       1
# 117 2020-06-01 09:39:20.021000+00:00  2020      6    1     9      39
#
# [118 rows x 14 columns]

# %%
u=df_2[['YEAR','MONTH','DAY','NAME','ID','POST-ID']]
u.groupby(['YEAR','MONTH','DAY']).first()
# Out:
#                                  NAME                        ID  \
# YEAR MONTH DAY
# 2020 3     26             Isis Amador  5e5855ced701ab08af792b51
#            27               Suman Ray  5e7de336a3258347b42f210e
#            28         Bhargav Prakash  5e783375cfc8b713f5ac7c5b
#            30      Rossend Bonàs Miró  5e822b86a3258347b42f2360
#            31           Nikhil Sharma  5e365e758d344822fed4d144
#      4     1            Vipul S Redey  5e840a75a3258347b42f2437
#            4                 Harshita  5e88156ca3258347b42f2542
#            5           Fauziya Shaikh  5e78ce84cfc8b713f5ac7cee
#            6             Udita Somani  5e8447a7a3258347b42f2446
#            7             Ayush Sharma  5e8cbd92a3258347b42f2699
#            10            Soumya Kumar  5e901d01a3258347b42f270f
#            11            Shivani Gaba  5e8437f6a3258347b42f243d
#            12           Shubham Kumar  5e92e380a3258347b42f278c
#            13   Nihal Singh Shekhawat  5e93d7d5a3258347b42f27e4
#            14                  Varsha  5e95da1aa3258347b42f29e6
#            15     Pratishtha Bhelonde  5e958e73a3258347b42f29a1
#            16     Elbassraoui Yassine  5e97ef3ea3258347b42f2b47
#            17         Lipika Moharana  5e8309c4a3258347b42f23f4
#            18             Parvez Khan  5df24eeaee4bb5252b4f5366
#            19             Kirti Ranka  5e9c146ba3258347b42f2cbd
#            21         Abhishank Gupta  5e9a8013a3258347b42f2c29
#            22             Harsh Nigam  5e99b0d4a3258347b42f2bf0
#            24            Priya Ranjan  5ea3191210426255a7aa9aa2
#            25         Nischaya Sharma  5d9a2982979d5962253c2f81
#            26             Rashi Rathi  5ea5ac4f10426255a7aa9b78
#            27               Raghunath  5ea6c05910426255a7aa9baa
#            28                Gretchen  5ea890e410426255a7aa9c16
#            29              Deep Patel  5eaa137910426255a7aa9c41
#            30          Abhishek Kumar  5ea83e8810426255a7aa9bf2
#      5     1         Avimanyu Samanta  5eab903b10426255a7aa9c8e
#            3            Kshitij Anand  5e7f4ad1a3258347b42f2155
#            5            Nimish Sharma  5e0d5ce12a37d20505da2a5d
#            8                   Apurba  5eb4f73910426255a7aaa0cc
#            10                    Isha  5eb7aeccfd92f539c465ddd7
#            11      Maaz Ahmad Rabbani  5ded443342a8854bf6eaba9a
#            12       Aayushree Khokhar  5e942f7ba3258347b42f280e
#            13                  Sushil  5ebc2ec4514aab59896bcc84
#            14           Rahul Agarwal  5ebcf2f2514aab59896bcd00
#            15           Arunav Moitra  5e4195c3eab55d319938a82c
#            18       Chavi Maheshwari.  5ec11abc74f7660d73aa0fbd
#            20                 Yoshita  5ec553e2f2781131cc7e5138
#            21        Angelina Christi  5df3f8f2ee4bb5252b4f5393
#            23              Rashi Jain  5e1ef04c2a37d20505da2b8b
#            24                  Shanya  5ec2204374f7660d73aa100f
#            25           Utkarsh Saini  5e37b16ceab55d319938a6f8
#            26        Kshitij Alawandi  5ecd5a5c7023451e662235c1
#            27           Aryan Malakar  5df20f1fee4bb5252b4f5351
#            28             Shreya Maji  5ecfdaa976027d35905cc02c
#            29                  Ashish  5ecf6e6576027d35905cbeec
#            30                    Neha  5ed2399b76027d35905cc70f
#            31     Rushikesh Chaudhari  5ed350ed76027d35905cca2c
#      6     1             Asif Hossain  5ed0defa76027d35905cc2de
#
#                                  POST-ID
# YEAR MONTH DAY
# 2020 3     26   5e7bd922cfc8b713f5ac7da9
#            27   5e733f1c1b24db0468e90cf1
#            28   5e7f39a3a3258347b42f2151
#            30   5e7304761b24db0468e90ce7
#            31   5e41bd7deab55d319938a839
#      4     1    5e4ed85af5561b1994c8e470
#            4    5e778ffccfc8b713f5ac7b50
#            5    5e78d6dccfc8b713f5ac7cf4
#            6    5e8448aba3258347b42f2447
#            7    5df64ad1cc709107827fb3dd
#            10   5e5e3b35fbc8805f69e02c9e
#            11   5e901b98a3258347b42f2708
#            12   5e04fb252a37d20505da2a2b
#            13   5df64ad1cc709107827fb3dd
#            14   5e95d427a3258347b42f29db
#            15   5e95f44ba3258347b42f2a31
#            16   5e7a0d85cfc8b713f5ac7d77
#            17   5e901b98a3258347b42f2708
#            18   5e9b0475a3258347b42f2c6b
#            19   5e9b6b20a3258347b42f2c8d
#            21   5e9f3e1aa3258347b42f2e39
#            22   5e9f3fd9a3258347b42f2e3f
#            24   5e733f1c1b24db0468e90cf1
#            25   5e767d501b24db0468e90d54
#            26   5e95f087a3258347b42f2a16
#            27   5e5bdf4fd701ab08af792bfd
#            28   5e895d87a3258347b42f25bb
#            29   5e5b6320d701ab08af792b9d
#            30   5d7d23315720533e15c3b1ee
#      5     1    5e5e3b35fbc8805f69e02c9e
#            3    5eaf4d4210426255a7aa9f76
#            5    5eaf8b9310426255a7aa9f7e
#            8    5e5e3b35fbc8805f69e02c9e
#            10   5e77c625cfc8b713f5ac7c0b
#            11   5dea816a42a8854bf6eaba89
#            12   5ea3227010426255a7aa9ac1
#            13   5e95f44ba3258347b42f2a31
#            14   5ea7cd9610426255a7aa9bd2
#            15   5eb2c11210426255a7aaa052
#            18   5ec2215374f7660d73aa1011
#            20   5ec5546bf2781131cc7e5140
#            21   5eba2e94514aab59896bcc5a
#            23   5ec3667274f7660d73aa1194
#            24   5ec821ddec493f4a2655889e
#            25   5e518c9fd701ab08af79299a
#            26   5e77738bcfc8b713f5ac7b36
#            27   5e502673d15de17a8cf1b946
#            28   5de8d73249e8203ff9219a74
#            29   5ec3c09274f7660d73aa1229
#            30   5e5facf649d7f322c033e02b
#            31   5eb4fab110426255a7aaa0ed
#      6     1    5eac305f10426255a7aa9dd3

# %%
detail=df_2.groupby(['NAME'])
x=detail.first()

# %%
# Enter any Candidate name and see all details which present in dataset.
name = x.loc[['Akhila Kota']]
name
# Out:
#                                    ID                   POST-ID  GENDER  \
# NAME
# Akhila Kota  5ea5bf5110426255a7aa9b88  5e9b6b20a3258347b42f2c8d  Female
#
#             ACADEMICS                           TITLE  \
# NAME
# Akhila Kota  Graduate  Rajasthan; An Absolute Beauty.
#
#                                CATEGORY POST-TYPE  \
# NAME
# Akhila Kota  Geography|Indian Geography      Blog
#
#                                    TIMESTAMP  YEAR  MONTH  DAY  HOUR  MINUTE
# NAME
# Akhila Kota 2020-04-26 19:21:27.749000+00:00  2020      4   26    19      21
